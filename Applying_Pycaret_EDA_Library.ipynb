# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
#lets import dataset
bank_df=pd.read_csv('Marketing_Analysis.csv')
bank_df.head(10)
# Out:
#    age           job   marital  education default  balance housing loan  \
# 0   58    management   married   tertiary      no     2143     yes   no
# 1   44    technician    single  secondary      no       29     yes   no
# 2   33  entrepreneur   married  secondary      no        2     yes  yes
# 3   47   blue-collar   married    unknown      no     1506     yes   no
# 4   33       unknown    single    unknown      no        1      no   no
# 5   35    management   married   tertiary      no      231     yes   no
# 6   28    management    single   tertiary      no      447     yes  yes
# 7   42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 8   58       retired   married    primary      no      121     yes   no
# 9   43    technician    single  secondary      no      593     yes   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no
# 5  unknown    5   may       139         1     -1         0  unknown  no
# 6  unknown    5   may       217         1     -1         0  unknown  no
# 7  unknown    5   may       380         1     -1         0  unknown  no
# 8  unknown    5   may        50         1     -1         0  unknown  no
# 9  unknown    5   may        55         1     -1         0  unknown  no

# %%
yes_df=bank_df[bank_df['y']=='yes']
yes_df.head()
# Out:
#      age         job  marital  education default  balance housing loan  \
# 83    59      admin.  married  secondary      no     2343     yes   no
# 86    56      admin.  married  secondary      no       45      no   no
# 87    41  technician  married  secondary      no     1270     yes   no
# 129   55    services  married  secondary      no     2476     yes   no
# 168   54      admin.  married   tertiary      no      184      no   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome    y
# 83   unknown    5   may      1042         1     -1         0  unknown  yes
# 86   unknown    5   may      1467         1     -1         0  unknown  yes
# 87   unknown    5   may      1389         1     -1         0  unknown  yes
# 129  unknown    5   may       579         1     -1         0  unknown  yes
# 168  unknown    5   may       673         2     -1         0  unknown  yes

# %%
success_df=bank_df[bank_df['poutcome']=='success']
success_df
# Out:
#        age            job   marital  education default  balance housing loan  \
# 24080   56     technician   married  secondary      no      589     yes   no
# 24165   30         admin.   married  secondary      no      873     yes   no
# 24239   48         admin.  divorced  secondary      no      295     yes   no
# 24264   49     management   married   tertiary      no       64      no   no
# 24435   42     technician   married   tertiary      no    14282     yes   no
# ...    ...            ...       ...        ...     ...      ...     ...  ...
# 45190   32    blue-collar   married  secondary      no      136      no   no
# 45193   28  self-employed    single   tertiary      no      159      no   no
# 45195   68        retired   married  secondary      no     1146      no   no
# 45201   53     management   married   tertiary      no      583      no   no
# 45208   72        retired   married  secondary      no     5715      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 24080    unknown   23   oct       518         1    147         2  success  yes
# 24165  telephone   12   nov       119         1    167         3  success   no
# 24239   cellular   17   nov       123         1    164         2  success   no
# 24264   cellular   17   nov       208         1    159         1  success   no
# 24435   cellular   17   nov        77         1    103         4  success   no
# ...          ...  ...   ...       ...       ...    ...       ...      ...  ...
# 45190   cellular   16   nov       206         1    188         3  success  yes
# 45193   cellular   16   nov       449         2     33         4  success  yes
# 45195   cellular   16   nov       212         1    187         6  success  yes
# 45201   cellular   17   nov       226         1    184         4  success  yes
# 45208   cellular   17   nov      1127         5    184         3  success  yes
#
# [1511 rows x 17 columns]

# %% [markdown]
# #### Dataset Description:
# <br>age : age of a customer
# <br>job : type of job
# <br>marital : marital status
# <br>education: education of customer
# <br>default : has credit in default? (yes or no)
# <br>balance : balance amount
# <br>housing : has housing loan? (yes or no)
# <br>loan : has a personal loan? (yes or no)
# <br>contact : contact communication type (cellular or telephone)
# <br>day : day of last contact
# <br>month : month of last contact
# <br>duration : last contact duration in seconds
# <br>campaign : number of times a customer was contacted during the campaign
# <br>pdays : number of days passed after the customer was last contacted from a previous campaign
# <br>previous : number of times the customer was contacted prior to (or before) this campaign
# <br>poutcome : outcome of the previous marketing campaign
# <br>y(target variable) : will the customer subscribe a term deposit?

# %%
# lets check the shape of the dataset
bank_df.shape
# Out:
# (45211, 17)

# %%
# lets check for null values
bank_df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %% [markdown]
# Hence, No null values present in the dataset

# %%
#lets check the datatypes of df
bank_df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
# categorical features
categorical_features=['job','marital','education','default','housing','loan','contact','month','poutcome']

# %%
# lets check the value counts for each categorical feature
for col in bank_df[categorical_features]:
    print(bank_df[col].value_counts())
    print('-'*75)
# Out:
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: job, dtype: int64
# ---------------------------------------------------------------------------
# married     27214
# single      12790
# divorced     5207
# Name: marital, dtype: int64
# ---------------------------------------------------------------------------
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: education, dtype: int64
# ---------------------------------------------------------------------------
# no     44396
# yes      815
# Name: default, dtype: int64
# ---------------------------------------------------------------------------
# yes    25130
# no     20081
# Name: housing, dtype: int64
# ---------------------------------------------------------------------------
# no     37967
# yes     7244
# Name: loan, dtype: int64
# ---------------------------------------------------------------------------
# cellular     29285
# unknown      13020
# telephone     2906
# Name: contact, dtype: int64
# ---------------------------------------------------------------------------
# may    13766
# jul     6895
# aug     6247
# jun     5341
# nov     3970
# apr     2932
# feb     2649
# jan     1403
# oct      738
# sep      579
# mar      477
# dec      214
# Name: month, dtype: int64
# ---------------------------------------------------------------------------
# unknown    36959
# failure     4901
# other       1840
# success     1511
# Name: poutcome, dtype: int64
# ---------------------------------------------------------------------------

# %%
# function to encode categorical variables
def Encode(df,variable):
    encoded_Variable = df[variable].value_counts().to_dict()
    df[variable] = df[variable].map(encoded_Variable)

# %%
for col in bank_df[categorical_features]:
    Encode(bank_df,col)

# %%
# lets check the dataset to check if categorical encoding happened or not
bank_df.head()
# Out:
#    age   job  marital  education  default  balance  housing   loan  contact  \
# 0   58  9458    27214      13301    44396     2143    25130  37967    13020
# 1   44  7597    12790      23202    44396       29    25130  37967    13020
# 2   33  1487    27214      23202    44396        2    25130   7244    13020
# 3   47  9732    27214       1857    44396     1506    25130  37967    13020
# 4   33   288    12790       1857    44396        1    20081  37967    13020
#
#    day  month  duration  campaign  pdays  previous  poutcome   y
# 0    5  13766       261         1     -1         0     36959  no
# 1    5  13766       151         1     -1         0     36959  no
# 2    5  13766        76         1     -1         0     36959  no
# 3    5  13766        92         1     -1         0     36959  no
# 4    5  13766       198         1     -1         0     36959  no

# %%
#lets check the value count of y
bank_df['y'].value_counts()
# Out:
# no     39922
# yes     5289
# Name: y, dtype: int64

# %%
# now lets label encode y output
label_map={'yes': 1, 'no': 0}
bank_df['y']=bank_df['y'].map(label_map)

# %%
#lets recheck the value count of y
bank_df['y'].value_counts()
# Out:
# 0    39922
# 1     5289
# Name: y, dtype: int64

# %%
# then the final processed dataset:
bank_df.head()
# Out:
#    age   job  marital  education  default  balance  housing   loan  contact  \
# 0   58  9458    27214      13301    44396     2143    25130  37967    13020
# 1   44  7597    12790      23202    44396       29    25130  37967    13020
# 2   33  1487    27214      23202    44396        2    25130   7244    13020
# 3   47  9732    27214       1857    44396     1506    25130  37967    13020
# 4   33   288    12790       1857    44396        1    20081  37967    13020
#
#    day  month  duration  campaign  pdays  previous  poutcome  y
# 0    5  13766       261         1     -1         0     36959  0
# 1    5  13766       151         1     -1         0     36959  0
# 2    5  13766        76         1     -1         0     36959  0
# 3    5  13766        92         1     -1         0     36959  0
# 4    5  13766       198         1     -1         0     36959  0

# %%
bank_df.to_csv('processed_data.csv',index=False)

# %%
final_df=pd.read_csv('processed_data2.csv')

# %% [markdown]
# ### Lets check with some EDA libraries and do some comparision to find the suitable model

# %% [markdown]
# ### Pycaret:

# %%
from pycaret.classification import *
clf1=setup(data=final_df,target='y')
# Out:
# <style  type="text/css" >
# </style><table id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row0_col1" class="data row0 col1" >1619</td>
#             </tr>
#             <tr>
#                         <th id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row1_col1" class="data row1 col1" >y</td>
#             </tr>
#             <tr>
#                         <th id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row4_col1" class="data row4 col1" >(45211, 16)</td>
#             </tr>
#             <tr>
#                         <th id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row6_col1" class="data row6 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row7_col1" class="data row7 col1" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row11_col1" class="data row11 col1" >(31647, 47)</td>
#             </tr>
#             <tr>
#                         <th id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row12_col1" class="data row12 col1" >(13564, 47)</td>
#             </tr>
#             <tr>
#                         <th id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_f973efc7_a721_11eb_ae82_040e3ca01bf7row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-6e764a0af66b> in <module>
#       1 from pycaret.classification import *
# ----> 2 clf1=setup(data=final_df,target='y')
#
# ~\anaconda3\lib\site-packages\pycaret\classification.py in setup(data, target, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs)
#     578         log_plots = ["auc", "confusion_matrix", "feature"]
#     579
# --> 580     return pycaret.internal.tabular.setup(
#     581         ml_usecase="classification",
#     582         available_plots=available_plots,
#
# ~\anaconda3\lib\site-packages\pycaret\internal\tabular.py in setup(data, target, ml_usecase, available_plots, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, transform_target, transform_target_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs, display)
#    1770     logger.info(f"display_container: {len(display_container)}")
#    1771
# -> 1772     logger.info(str(prep_pipe))
#    1773     logger.info("setup() succesfully completed......................................")
#    1774
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in __repr__(self, N_CHAR_MAX)
#     258             n_max_elements_to_show=N_MAX_ELEMENTS_TO_SHOW)
#     259
# --> 260         repr_ = pp.pformat(self)
#     261
#     262         # Use bruteforce ellipsis when there are a lot of non-blank characters
#
# ~\anaconda3\lib\pprint.py in pformat(self, object)
#     151     def pformat(self, object):
#     152         sio = _StringIO()
# --> 153         self._format(object, sio, 0, 0, {}, 0)
#     154         return sio.getvalue()
#     155
#
# ~\anaconda3\lib\pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     168             self._readable = False
#     169             return
# --> 170         rep = self._repr(object, context, level)
#     171         max_width = self._width - indent - allowance
#     172         if len(rep) > max_width:
#
# ~\anaconda3\lib\pprint.py in _repr(self, object, context, level)
#     402
#     403     def _repr(self, object, context, level):
# --> 404         repr, readable, recursive = self.format(object, context.copy(),
#     405                                                 self._depth, level)
#     406         if not readable:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\_pprint.py in format(self, object, context, maxlevels, level)
#     178
#     179     def format(self, object, context, maxlevels, level):
# --> 180         return _safe_repr(object, context, maxlevels, level,
#     181                           changed_only=self._changed_only)
#     182
#
# ~\anaconda3\lib\site-packages\sklearn\utils\_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     434             krepr, kreadable, krecur = saferepr(
#     435                 k, context, maxlevels, level, changed_only=changed_only)
# --> 436             vrepr, vreadable, vrecur = saferepr(
#     437                 v, context, maxlevels, level, changed_only=changed_only)
#     438             append("%s=%s" % (krepr.strip("'"), vrepr))
#
# ~\anaconda3\lib\site-packages\sklearn\utils\_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     403         level += 1
#     404         for o in object:
# --> 405             orepr, oreadable, orecur = _safe_repr(
#     406                 o, context, maxlevels, level, changed_only=changed_only)
#     407             append(orepr)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     403         level += 1
#     404         for o in object:
# --> 405             orepr, oreadable, orecur = _safe_repr(
#     406                 o, context, maxlevels, level, changed_only=changed_only)
#     407             append(orepr)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     425             params = _changed_params(object)
#     426         else:
# --> 427             params = object.get_params(deep=False)
#     428         components = []
#     429         append = components.append
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in get_params(self, deep)
#     193         out = dict()
#     194         for key in self._get_param_names():
# --> 195             value = getattr(self, key)
#     196             if deep and hasattr(value, 'get_params'):
#     197                 deep_items = value.get_params().items()
#
# AttributeError: 'Simple_Imputer' object has no attribute 'fill_value_categorical'

# %%
best_model = compare_models()
# Out:
# <style  type="text/css" >
#     #T_55e114ac_a722_11eb_aa45_040e3ca01bf7 th {
#           text-align: left;
#     }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row0_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row0_col1 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row0_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row0_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row0_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row0_col5 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row0_col6 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row0_col7 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row0_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row1_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row1_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row1_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row1_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row1_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row1_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row1_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row1_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row1_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row2_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row2_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row2_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row2_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row2_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row2_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row2_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row2_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row2_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row3_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row3_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row3_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row3_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row3_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row3_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row3_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row3_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row3_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row4_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row4_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row4_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row4_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row4_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row4_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row4_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row4_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row4_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row5_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row5_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row5_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row5_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row5_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row5_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row5_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row5_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_55e114ac_a722_11eb_aa45_040e3ca01bf7row5_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;

# %%
print(best_model)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=1619, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
#lets create model object for the best model
#lgbm_model=create_model('lightgbm')

# %%
#lets check feature importance using this model
#plot_model(lgbm_model,plot='feature')

# %%
# lets check confusion matrix
#plot_model(lgbm_model, plot = 'confusion_matrix')

# %%
# another way to evaluate model is:
#evaluate_model(lgbm_model)

# %% [markdown]
# #### we can check prediction on new data using this approach
# <br>unseen_predictions = predict_model(lgbm_model, data=data_unseen)
# <br>unseen_predictions.head()

# %% [markdown]
# ### saving the model:
# <br>save_model( lgbm_model,'lgbm_model')
# <br>here we are not saving the model, as the model pickle file comes with pyret dependencies, i faced issue during flask deployment.

# %%
top12=compare_models(n_select=13)
# Out:
# <style  type="text/css" >
#     #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7 th {
#           text-align: left;
#     }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row0_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row0_col1 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row0_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row0_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row0_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row0_col5 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row0_col6 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row0_col7 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row0_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row1_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row1_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row1_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row1_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row1_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row1_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row1_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row1_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row1_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row2_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row2_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row2_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row2_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row2_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row2_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row2_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row2_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row2_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row3_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row3_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row3_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row3_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row3_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row3_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row3_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row3_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row3_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row4_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row4_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row4_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row4_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row4_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row4_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row4_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row4_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row4_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row5_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row5_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row5_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row5_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row5_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row5_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row5_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row5_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_e4cabbb3_a722_11eb_b53f_040e3ca01bf7row5_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;

# %%
print(top12)
# Out:
# [LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=1619, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0), GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, random_state=1619,
#                            subsample=1.0, tol=0.0001, validation_fraction=0.1,
#                            verbose=0, warm_start=False), RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=1619, verbose=0,
#                        warm_start=False), LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=1619, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), LinearDiscriminantAnalysis(covariance_estimator=None, n_components=None,
#                            priors=None, shrinkage=None, solver='svd',
#                            store_covariance=False, tol=0.0001), AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1.0,
#                    n_estimators=50, random_state=1619), RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#                 max_iter=None, normalize=False, random_state=1619,
#                 solver='auto', tol=0.001), ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=1619, verbose=0,
#                      warm_start=False), DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=1619,
#                        splitter='best'), GaussianNB(priors=None, var_smoothing=1e-09), SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#               early_stopping=False, epsilon=0.1, eta0=0.001, fit_intercept=True,
#               l1_ratio=0.15, learning_rate='optimal', loss='hinge',
#               max_iter=1000, n_iter_no_change=5, n_jobs=-1, penalty='l2',
#               power_t=0.5, random_state=1619, shuffle=True, tol=0.001,
#               validation_fraction=0.1, verbose=0, warm_start=False), KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                      weights='uniform'), QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001)]
